# %% [markdown]
# # Deep Q-Network with Tensorflow
#
# Implementing a DQN using tensorflow and solving the lunar lander
#
# ### 1. Import the required packages

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy

import gym
import random
import numpy as np
from collections import namedtuple, deque
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 2. Instantiate the Environment and Agent
#
# Initialize the environment in the code cell below.

# %%
env = gym.make('LunarLander-v2')
env.seed(0)
print('State shape: ', env.observation_space.shape)
print('Number of actions: ', env.action_space.n)
# Out:
# State shape:  (8,)
# Number of actions:  4

# %% [markdown]
# ### Define the Model

# %%
class QNetwork():

    def __init__(self, state_size, action_size, seed, fc1_units=64, fc2_units=64):
        self.model = Sequential([
            Dense(units=fc1_units, input_shape=(state_size,), activation='relu'),
            Dense(units=fc2_units, activation='relu'),
            Dense(units=action_size, activation='relu'),
        ])
    
        self.model.compile(optimizer=Adam(learning_rate=0.0001), loss="mean_squared_error")
        
        self.action_size = action_size

    def forward(self, state):

        return self.model.predict(x=np.array([state]))

    def learn(self, samples, labels, batch_size=32, epochs=100, verbose=2):
        self.model.fit(x=samples, y=labels, epochs=epochs, verbose=0)
        
    def save(self, location):
        tf.keras.models.save_model(self.model, location)

# %% [markdown]
# ### Define the Agent

# %%
BUFFER_SIZE = 1000  # replay buffer size
BATCH_SIZE = 64         # minibatch size
GAMMA = 0.99            # discount factor
TAU = 0.001              # for soft update of target parameters
LR = 0.0005               # learning rate 
UPDATE_EVERY = 500        # how often to update the network

class Agent():
    """Interacts with and learns from the environment."""

    def __init__(self, state_size, action_size, seed):
        """Initialize an Agent object.
        
        Params
        ======
            state_size (int): dimension of each state
            action_size (int): dimension of each action
            seed (int): random seed
        """
        self.state_size = state_size
        self.action_size = action_size
        self.seed = random.seed(seed)

        # Q-Network
        self.qnetwork_local = QNetwork(state_size, action_size, seed)
        self.qnetwork_target = QNetwork(state_size, action_size, seed)
        
        self.copy_network(self.qnetwork_local , self.qnetwork_target)
        
        self.memory = ReplayBuffer(action_size, BUFFER_SIZE, BATCH_SIZE, seed)

        self.t_step = 0
    
    def step(self, state, action, reward, next_state, done, skip_learn=False):

        self.memory.add(state, action, reward, next_state, done)
        
        # Learn every UPDATE_EVERY time steps.
        self.t_step = (self.t_step + 1) % UPDATE_EVERY
        if self.t_step == 0:
            # If enough samples are available in memory, get random subset and learn
            if len(self.memory) >= BUFFER_SIZE and not skip_learn:
                experiences = self.memory.sample()
                self.learn(experiences, GAMMA)

    def act(self, state, eps=0.):
        action_values = self.qnetwork_local.forward(state)

        # Epsilon-greedy action selection
        if random.random() > eps:
            return np.argmax(action_values)
        else:
            return random.choice(np.arange(self.action_size))

    def learn(self, experiences, gamma):
        states, actions, rewards, next_states, dones = experiences

        # Get max predicted Q values (for next states) from target model
        Q_targets_next = []
        i =0
        for state in next_states:
            output = self.qnetwork_target.forward(state)[0]
            output[actions[i]] =rewards[i]
            Q_targets_next.append(output)
            i +=1
        # Compute Q targets for current states 
        Q_targets = [] 
        
        i =0
        for reward in rewards:
            reward + (gamma * Q_targets_next[i] * (1 - dones[i]))
            i +=1
            Q_targets.append(reward)
        
        Q_targets = np.array(Q_targets)
        


        self.qnetwork_local.learn(states,Q_targets)

        # ------------------- update target network ------------------- #
        self.soft_update_target(TAU)                     

    def copy_network(self, local_model, target_model):
        target_model_update = tf.keras.models.clone_model(local_model.model)
        target_model.model = target_model_update
        
    def soft_update_target(self, TAU):
        target_weights = np.array(self.qnetwork_target.model.get_weights())
        local_weights = np.array(self.qnetwork_local.model.get_weights())
        self.qnetwork_target.model.set_weights(target_weights + TAU*(local_weights-target_weights))

    
    def save(self):
        self.qnetwork_target.save("checkpoint.target.ckpt")
        self.qnetwork_local.save("checkpoint.local.ckpt")
    


class ReplayBuffer:
    """Fixed-size buffer to store experience tuples."""

    def __init__(self, action_size, buffer_size, batch_size, seed):
        """Initialize a ReplayBuffer object.

        Params
        ======
            action_size (int): dimension of each action
            buffer_size (int): maximum size of buffer
            batch_size (int): size of each training batch
            seed (int): random seed
        """
        self.action_size = action_size
        self.memory = deque(maxlen=buffer_size)  
        self.batch_size = batch_size
        self.experience = namedtuple("Experience", field_names=["state", "action", "reward", "next_state", "done"])
        self.seed = random.seed(seed)
    
    def add(self, state, action, reward, next_state, done):
        """Add a new experience to memory."""
        e = self.experience(state, action, reward, next_state, done)
        self.memory.append(e)
    
    def sample(self):
        """Randomly sample a batch of experiences from memory."""
        experiences = random.sample(self.memory, k=self.batch_size)

        states = np.vstack([e.state for e in experiences if e is not None])
        actions = np.vstack([e.action for e in experiences if e is not None])
        rewards = np.vstack([e.reward for e in experiences if e is not None])
        next_states = np.vstack([e.next_state for e in experiences if e is not None])
        dones = np.vstack([e.done for e in experiences if e is not None])
  
        return (states, actions, rewards, next_states, dones)

    def __len__(self):
        """Return the current size of internal memory."""
        return len(self.memory)

# %% [markdown]
# ## Watch an untrained agent

# %%
agent = Agent(state_size=8, action_size=4, seed=0)

# watch an untrained agent
state = env.reset()
for j in range(200):
    action = agent.act(state)
    env.render()
    state, reward, done, _ = env.step(action)
    if done:
        break 
        
env.close()

# %% [markdown]
# ### Lets Train an agent

# %%
agent = Agent(state_size=8, action_size=4, seed=0)

def dqn(n_episodes=2000, max_t=1000, eps_start=1.0, eps_end=0.01, eps_decay=0.995):
    
    # We need to start with some random games
    random_game_count = 0
    state = env.reset()
    while len(agent.memory) < BUFFER_SIZE:
        random_game_count += 1
        state = env.reset()
        score = 0
        done = False
        step_num = 1
        while not done:

            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done, skip_learn=True)
            state = next_state
            score += reward
            
        if random_game_count%10 == 0:
            print("Random Game Count: "+ str(random_game_count))
            print("Memory Size: "+ str(len(agent.memory)))
            
    print("Done Filling Up memory")
 
    
    
    scores = []                        # list containing scores from each episode
    scores_window = deque(maxlen=100)  # last 100 scores
    eps = eps_start                    # initialize epsilon
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        score = 0
        for t in range(max_t):
            action = agent.act(state, eps)
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                
                break 
        scores_window.append(score)       # save most recent score
        scores.append(score)              # save most recent score
        eps = max(eps_end, eps_decay*eps) # decrease epsilon
        print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)), end="")
        print(' Epsilon: '+str(eps))
        if i_episode % 10 == 0:
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_window)))
            agent.save()
        if np.mean(scores_window)>=200.0:
            print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i_episode-100, np.mean(scores_window)))
            torch.save(agent.qnetwork_local.state_dict(), 'checkpoint.pth')
            break
    return scores

scores = dqn()

# plot the scores
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Random Game Count: 10
# Memory Size: 649
# Done Filling Up memory
# Episode 1	Average Score: -319.33 Epsilon: 0.995
# Episode 2	Average Score: -192.40 Epsilon: 0.990025
# Episode 3	Average Score: -197.77 Epsilon: 0.985074875
# Episode 4	Average Score: -209.69 Epsilon: 0.9801495006250001
# Episode 5	Average Score: -226.04 Epsilon: 0.9752487531218751
# Episode 6	Average Score: -240.40 Epsilon: 0.9703725093562657
# Episode 7	Average Score: -234.22 Epsilon: 0.9655206468094844
# Episode 8	Average Score: -215.09 Epsilon: 0.960693043575437
# Episode 9	Average Score: -201.18 Epsilon: 0.9558895783575597
# Episode 10	Average Score: -191.18 Epsilon: 0.9511101304657719
# Episode 10	Average Score: -191.18
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 11	Average Score: -187.69 Epsilon: 0.946354579813443
# Episode 12	Average Score: -181.87 Epsilon: 0.9416228069143757
# Episode 13	Average Score: -185.28 Epsilon: 0.9369146928798039
# Episode 14	Average Score: -180.97 Epsilon: 0.9322301194154049
# Episode 15	Average Score: -181.59 Epsilon: 0.9275689688183278
# Episode 16	Average Score: -189.59 Epsilon: 0.9229311239742362
# Episode 17	Average Score: -200.73 Epsilon: 0.918316468354365
# Episode 18	Average Score: -199.20 Epsilon: 0.9137248860125932
# Episode 19	Average Score: -193.17 Epsilon: 0.9091562615825302
# Episode 20	Average Score: -190.54 Epsilon: 0.9046104802746175
# Episode 20	Average Score: -190.54
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 21	Average Score: -186.32 Epsilon: 0.9000874278732445
# Episode 22	Average Score: -183.70 Epsilon: 0.8955869907338783
# Episode 23	Average Score: -180.58 Epsilon: 0.8911090557802088
# Episode 24	Average Score: -178.27 Epsilon: 0.8866535105013078
# Episode 25	Average Score: -174.66 Epsilon: 0.8822202429488013
# Episode 26	Average Score: -170.52 Epsilon: 0.8778091417340573
# Episode 27	Average Score: -169.15 Epsilon: 0.8734200960253871
# Episode 28	Average Score: -166.31 Epsilon: 0.8690529955452602
# Episode 29	Average Score: -169.42 Epsilon: 0.8647077305675338
# Episode 30	Average Score: -167.24 Epsilon: 0.8603841919146962
# Episode 30	Average Score: -167.24
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 31	Average Score: -165.52 Epsilon: 0.8560822709551227
# Episode 32	Average Score: -162.37 Epsilon: 0.851801859600347
# Episode 33	Average Score: -163.40 Epsilon: 0.8475428503023453
# Episode 34	Average Score: -164.66 Epsilon: 0.8433051360508336
# Episode 35	Average Score: -167.29 Epsilon: 0.8390886103705794
# Episode 36	Average Score: -164.48 Epsilon: 0.8348931673187264
# Episode 37	Average Score: -163.51 Epsilon: 0.8307187014821328
# Episode 38	Average Score: -170.60 Epsilon: 0.8265651079747222
# Episode 39	Average Score: -169.38 Epsilon: 0.8224322824348486
# Episode 40	Average Score: -170.09 Epsilon: 0.8183201210226743
# Episode 40	Average Score: -170.09
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 41	Average Score: -171.21 Epsilon: 0.8142285204175609
# Episode 42	Average Score: -170.86 Epsilon: 0.810157377815473
# Episode 43	Average Score: -169.20 Epsilon: 0.8061065909263957
# Episode 44	Average Score: -170.33 Epsilon: 0.8020760579717637
# Episode 45	Average Score: -169.29 Epsilon: 0.798065677681905
# Episode 46	Average Score: -168.06 Epsilon: 0.7940753492934954
# Episode 47	Average Score: -171.33 Epsilon: 0.7901049725470279
# Episode 48	Average Score: -169.78 Epsilon: 0.7861544476842928
# Episode 49	Average Score: -168.16 Epsilon: 0.7822236754458713
# Episode 50	Average Score: -167.26 Epsilon: 0.778312557068642
# Episode 50	Average Score: -167.26
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 51	Average Score: -166.86 Epsilon: 0.7744209942832988
# Episode 52	Average Score: -165.09 Epsilon: 0.7705488893118823
# Episode 53	Average Score: -162.43 Epsilon: 0.7666961448653229
# Episode 54	Average Score: -163.24 Epsilon: 0.7628626641409962
# Episode 55	Average Score: -162.53 Epsilon: 0.7590483508202912
# Episode 56	Average Score: -159.63 Epsilon: 0.7552531090661897
# Episode 57	Average Score: -159.89 Epsilon: 0.7514768435208588
# Episode 58	Average Score: -159.61 Epsilon: 0.7477194593032545
# Episode 59	Average Score: -162.65 Epsilon: 0.7439808620067382
# Episode 60	Average Score: -162.05 Epsilon: 0.7402609576967045
# Episode 60	Average Score: -162.05
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 61	Average Score: -160.48 Epsilon: 0.736559652908221
# Episode 62	Average Score: -160.50 Epsilon: 0.7328768546436799
# Episode 63	Average Score: -158.96 Epsilon: 0.7292124703704616
# Episode 64	Average Score: -160.64 Epsilon: 0.7255664080186093
# Episode 65	Average Score: -158.77 Epsilon: 0.7219385759785162
# Episode 66	Average Score: -158.46 Epsilon: 0.7183288830986236
# Episode 67	Average Score: -159.21 Epsilon: 0.7147372386831305
# Episode 68	Average Score: -158.49 Epsilon: 0.7111635524897149
# Episode 69	Average Score: -159.89 Epsilon: 0.7076077347272662
# Episode 70	Average Score: -159.40 Epsilon: 0.7040696960536299
# Episode 70	Average Score: -159.40
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 71	Average Score: -158.28 Epsilon: 0.7005493475733617
# Episode 72	Average Score: -157.15 Epsilon: 0.697046600835495
# Episode 73	Average Score: -156.57 Epsilon: 0.6935613678313175
# Episode 74	Average Score: -155.31 Epsilon: 0.6900935609921609
# Episode 75	Average Score: -154.45 Epsilon: 0.6866430931872001
# Episode 76	Average Score: -154.93 Epsilon: 0.6832098777212641
# Episode 77	Average Score: -154.33 Epsilon: 0.6797938283326578
# Episode 78	Average Score: -153.51 Epsilon: 0.6763948591909945
# Episode 79	Average Score: -153.00 Epsilon: 0.6730128848950395
# Episode 80	Average Score: -152.11 Epsilon: 0.6696478204705644
# Episode 80	Average Score: -152.11
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 81	Average Score: -150.00 Epsilon: 0.6662995813682115
# Episode 82	Average Score: -151.43 Epsilon: 0.6629680834613705
# Episode 83	Average Score: -151.49 Epsilon: 0.6596532430440636
# Episode 84	Average Score: -154.97 Epsilon: 0.6563549768288433
# Episode 85	Average Score: -154.45 Epsilon: 0.653073201944699
# Episode 86	Average Score: -154.44 Epsilon: 0.6498078359349755
# Episode 87	Average Score: -154.61 Epsilon: 0.6465587967553006
# Episode 88	Average Score: -154.10 Epsilon: 0.6433260027715241
# Episode 89	Average Score: -152.68 Epsilon: 0.6401093727576664
# Episode 90	Average Score: -152.24 Epsilon: 0.6369088258938781
# Episode 90	Average Score: -152.24
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 91	Average Score: -152.28 Epsilon: 0.6337242817644086
# Episode 92	Average Score: -152.33 Epsilon: 0.6305556603555866
# Episode 93	Average Score: -152.20 Epsilon: 0.6274028820538087
# Episode 94	Average Score: -155.10 Epsilon: 0.6242658676435396
# Episode 95	Average Score: -154.51 Epsilon: 0.6211445383053219
# Episode 96	Average Score: -154.43 Epsilon: 0.6180388156137953
# Episode 97	Average Score: -154.42 Epsilon: 0.6149486215357263
# Episode 98	Average Score: -155.01 Epsilon: 0.6118738784280476
# Episode 99	Average Score: -153.99 Epsilon: 0.6088145090359074
# Episode 100	Average Score: -153.73 Epsilon: 0.6057704364907278
# Episode 100	Average Score: -153.73
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 101	Average Score: -151.71 Epsilon: 0.6027415843082742
# Episode 102	Average Score: -153.64 Epsilon: 0.5997278763867329
# Episode 103	Average Score: -152.96 Epsilon: 0.5967292370047992
# Episode 104	Average Score: -151.13 Epsilon: 0.5937455908197752
# Episode 105	Average Score: -149.31 Epsilon: 0.5907768628656763
# Episode 106	Average Score: -148.17 Epsilon: 0.5878229785513479
# Episode 107	Average Score: -150.73 Epsilon: 0.5848838636585911
# Episode 108	Average Score: -152.11 Epsilon: 0.5819594443402982
# Episode 109	Average Score: -152.70 Epsilon: 0.5790496471185967
# Episode 110	Average Score: -153.34 Epsilon: 0.5761543988830038
# Episode 110	Average Score: -153.34
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 111	Average Score: -152.93 Epsilon: 0.5732736268885887
# Episode 112	Average Score: -153.52 Epsilon: 0.5704072587541458
# Episode 113	Average Score: -153.02 Epsilon: 0.567555222460375
# Episode 114	Average Score: -152.96 Epsilon: 0.5647174463480732
# Episode 115	Average Score: -152.03 Epsilon: 0.5618938591163328
# Episode 116	Average Score: -151.58 Epsilon: 0.5590843898207511
# Episode 117	Average Score: -149.03 Epsilon: 0.5562889678716474
# Episode 118	Average Score: -148.44 Epsilon: 0.5535075230322891
# Episode 119	Average Score: -150.25 Epsilon: 0.5507399854171277
# Episode 120	Average Score: -150.06 Epsilon: 0.547986285490042
# Episode 120	Average Score: -150.06
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 121	Average Score: -149.65 Epsilon: 0.5452463540625918
# Episode 122	Average Score: -149.94 Epsilon: 0.5425201222922789
# Episode 123	Average Score: -149.70 Epsilon: 0.5398075216808175
# Episode 124	Average Score: -149.30 Epsilon: 0.5371084840724134
# Episode 125	Average Score: -149.62 Epsilon: 0.5344229416520513
# Episode 126	Average Score: -150.22 Epsilon: 0.531750826943791
# Episode 127	Average Score: -150.20 Epsilon: 0.5290920728090721
# Episode 128	Average Score: -150.59 Epsilon: 0.5264466124450268
# Episode 129	Average Score: -148.93 Epsilon: 0.5238143793828016
# Episode 130	Average Score: -149.36 Epsilon: 0.5211953074858876
# Episode 130	Average Score: -149.36
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 131	Average Score: -149.78 Epsilon: 0.5185893309484582
# Episode 132	Average Score: -150.34 Epsilon: 0.5159963842937159
# Episode 133	Average Score: -149.62 Epsilon: 0.5134164023722473
# Episode 134	Average Score: -148.94 Epsilon: 0.510849320360386
# Episode 135	Average Score: -146.16 Epsilon: 0.5082950737585841
# Episode 136	Average Score: -147.00 Epsilon: 0.5057535983897912
# Episode 137	Average Score: -146.56 Epsilon: 0.5032248303978422
# Episode 138	Average Score: -144.34 Epsilon: 0.500708706245853
# Episode 139	Average Score: -144.72 Epsilon: 0.4982051627146237
# Episode 140	Average Score: -146.02 Epsilon: 0.49571413690105054
# Episode 140	Average Score: -146.02
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 141	Average Score: -145.71 Epsilon: 0.4932355662165453
# Episode 142	Average Score: -145.87 Epsilon: 0.4907693883854626
# Episode 143	Average Score: -146.01 Epsilon: 0.4883155414435353
# Episode 144	Average Score: -145.35 Epsilon: 0.4858739637363176
# Episode 145	Average Score: -145.96 Epsilon: 0.483444593917636
# Episode 146	Average Score: -145.83 Epsilon: 0.4810273709480478
# Episode 147	Average Score: -143.62 Epsilon: 0.47862223409330756
# Episode 148	Average Score: -144.08 Epsilon: 0.47622912292284103
# Episode 149	Average Score: -144.97 Epsilon: 0.4738479773082268
# Episode 150	Average Score: -144.86 Epsilon: 0.47147873742168567
# Episode 150	Average Score: -144.86
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 151	Average Score: -144.81 Epsilon: 0.46912134373457726
# Episode 152	Average Score: -145.04 Epsilon: 0.46677573701590436
# Episode 153	Average Score: -145.71 Epsilon: 0.46444185833082485
# Episode 154	Average Score: -144.70 Epsilon: 0.46211964903917074
# Episode 155	Average Score: -145.09 Epsilon: 0.4598090507939749
# Episode 156	Average Score: -146.30 Epsilon: 0.457510005540005
# Episode 157	Average Score: -145.80 Epsilon: 0.45522245551230495
# Episode 158	Average Score: -145.43 Epsilon: 0.4529463432347434
# Episode 159	Average Score: -141.90 Epsilon: 0.4506816115185697
# Episode 160	Average Score: -142.47 Epsilon: 0.4484282034609769
# Episode 160	Average Score: -142.47
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 161	Average Score: -143.88 Epsilon: 0.446186062443672
# Episode 162	Average Score: -143.64 Epsilon: 0.4439551321314536
# Episode 163	Average Score: -143.82 Epsilon: 0.4417353564707963
# Episode 164	Average Score: -142.30 Epsilon: 0.43952667968844233
# Episode 165	Average Score: -143.44 Epsilon: 0.43732904629000013
# Episode 166	Average Score: -143.78 Epsilon: 0.4351424010585501
# Episode 167	Average Score: -142.64 Epsilon: 0.43296668905325736
# Episode 168	Average Score: -142.98 Epsilon: 0.43080185560799106
# Episode 169	Average Score: -141.40 Epsilon: 0.4286478463299511
# Episode 170	Average Score: -141.35 Epsilon: 0.42650460709830135
# Episode 170	Average Score: -141.35
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 171	Average Score: -141.52 Epsilon: 0.42437208406280985
# Episode 172	Average Score: -142.24 Epsilon: 0.4222502236424958
# Episode 173	Average Score: -142.25 Epsilon: 0.42013897252428334
# Episode 174	Average Score: -142.81 Epsilon: 0.4180382776616619
# Episode 175	Average Score: -143.14 Epsilon: 0.4159480862733536
# Episode 176	Average Score: -143.72 Epsilon: 0.41386834584198684
# Episode 177	Average Score: -143.37 Epsilon: 0.4117990041127769
# Episode 178	Average Score: -143.49 Epsilon: 0.40974000909221303
# Episode 179	Average Score: -143.95 Epsilon: 0.40769130904675194
# Episode 180	Average Score: -144.70 Epsilon: 0.40565285250151817
# Episode 180	Average Score: -144.70
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 181	Average Score: -148.44 Epsilon: 0.4036245882390106
# Episode 182	Average Score: -147.02 Epsilon: 0.4016064652978155
# Episode 183	Average Score: -146.68 Epsilon: 0.3995984329713264
# Episode 184	Average Score: -143.64 Epsilon: 0.3976004408064698
# Episode 185	Average Score: -144.24 Epsilon: 0.39561243860243744
# Episode 186	Average Score: -143.95 Epsilon: 0.3936343764094253
# Episode 187	Average Score: -143.33 Epsilon: 0.39166620452737816
# Episode 188	Average Score: -143.12 Epsilon: 0.3897078735047413
# Episode 189	Average Score: -144.51 Epsilon: 0.3877593341372176
# Episode 190	Average Score: -148.42 Epsilon: 0.3858205374665315
# Episode 190	Average Score: -148.42
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 191	Average Score: -147.95 Epsilon: 0.38389143477919885
# Episode 192	Average Score: -147.63 Epsilon: 0.3819719776053028
# Episode 193	Average Score: -148.02 Epsilon: 0.3800621177172763
# Episode 194	Average Score: -145.09 Epsilon: 0.37816180712868996
# Episode 195	Average Score: -146.20 Epsilon: 0.37627099809304654
# Episode 196	Average Score: -146.93 Epsilon: 0.3743896431025813
# Episode 197	Average Score: -147.56 Epsilon: 0.37251769488706843
# Episode 198	Average Score: -146.45 Epsilon: 0.3706551064126331
# Episode 199	Average Score: -147.21 Epsilon: 0.36880183088056995
# Episode 200	Average Score: -147.53 Epsilon: 0.3669578217261671
# Episode 200	Average Score: -147.53
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 201	Average Score: -148.10 Epsilon: 0.36512303261753626
# Episode 202	Average Score: -147.82 Epsilon: 0.3632974174544486
# Episode 203	Average Score: -145.97 Epsilon: 0.3614809303671764
# Episode 204	Average Score: -146.83 Epsilon: 0.3596735257153405
# Episode 205	Average Score: -146.87 Epsilon: 0.3578751580867638
# Episode 206	Average Score: -146.21 Epsilon: 0.35608578229633
# Episode 207	Average Score: -143.00 Epsilon: 0.3543053533848483
# Episode 208	Average Score: -141.65 Epsilon: 0.35253382661792404
# Episode 209	Average Score: -141.20 Epsilon: 0.3507711574848344
# Episode 210	Average Score: -140.64 Epsilon: 0.34901730169741024
# Episode 210	Average Score: -140.64
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 211	Average Score: -140.90 Epsilon: 0.3472722151889232
# Episode 212	Average Score: -140.33 Epsilon: 0.3455358541129786
# Episode 213	Average Score: -140.72 Epsilon: 0.3438081748424137
# Episode 214	Average Score: -140.42 Epsilon: 0.3420891339682016
# Episode 215	Average Score: -141.43 Epsilon: 0.3403786882983606
# Episode 216	Average Score: -140.11 Epsilon: 0.3386767948568688
# Episode 217	Average Score: -140.78 Epsilon: 0.33698341088258443
# Episode 218	Average Score: -141.74 Epsilon: 0.3352984938281715
# Episode 219	Average Score: -140.36 Epsilon: 0.33362200135903064
# Episode 220	Average Score: -140.30 Epsilon: 0.33195389135223546
# Episode 220	Average Score: -140.30
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 221	Average Score: -139.90 Epsilon: 0.3302941218954743
# Episode 222	Average Score: -139.34 Epsilon: 0.32864265128599696
# Episode 223	Average Score: -139.62 Epsilon: 0.326999438029567
# Episode 224	Average Score: -141.04 Epsilon: 0.3253644408394192
# Episode 225	Average Score: -141.77 Epsilon: 0.3237376186352221
# Episode 226	Average Score: -141.91 Epsilon: 0.322118930542046
# Episode 227	Average Score: -142.03 Epsilon: 0.32050833588933575
# Episode 228	Average Score: -143.01 Epsilon: 0.31890579420988907
# Episode 229	Average Score: -144.11 Epsilon: 0.3173112652388396
# Episode 230	Average Score: -142.93 Epsilon: 0.3157247089126454
# Episode 230	Average Score: -142.93
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 231	Average Score: -142.54 Epsilon: 0.3141460853680822
# Episode 232	Average Score: -142.66 Epsilon: 0.3125753549412418
# Episode 233	Average Score: -142.50 Epsilon: 0.31101247816653554
# Episode 234	Average Score: -143.34 Epsilon: 0.30945741577570285
# Episode 235	Average Score: -144.74 Epsilon: 0.3079101286968243
# Episode 236	Average Score: -144.08 Epsilon: 0.3063705780533402
# Episode 237	Average Score: -144.25 Epsilon: 0.30483872516307353
# Episode 238	Average Score: -145.25 Epsilon: 0.3033145315372582
# Episode 239	Average Score: -144.79 Epsilon: 0.3017979588795719
# Episode 240	Average Score: -142.80 Epsilon: 0.30028896908517405
# Episode 240	Average Score: -142.80
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 241	Average Score: -143.02 Epsilon: 0.2987875242397482
# Episode 242	Average Score: -142.60 Epsilon: 0.29729358661854943
# Episode 243	Average Score: -143.15 Epsilon: 0.29580711868545667
# Episode 244	Average Score: -142.81 Epsilon: 0.2943280830920294
# Episode 245	Average Score: -142.30 Epsilon: 0.29285644267656924
# Episode 246	Average Score: -142.88 Epsilon: 0.2913921604631864
# Episode 247	Average Score: -143.57 Epsilon: 0.28993519966087045
# Episode 248	Average Score: -143.38 Epsilon: 0.2884855236625661
# Episode 249	Average Score: -142.95 Epsilon: 0.28704309604425327
# Episode 250	Average Score: -143.06 Epsilon: 0.285607880564032
# Episode 250	Average Score: -143.06
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 251	Average Score: -142.62 Epsilon: 0.28417984116121187
# Episode 252	Average Score: -142.87 Epsilon: 0.2827589419554058
# Episode 253	Average Score: -143.55 Epsilon: 0.28134514724562876
# Episode 254	Average Score: -142.99 Epsilon: 0.2799384215094006
# Episode 255	Average Score: -142.21 Epsilon: 0.27853872940185365
# Episode 256	Average Score: -142.38 Epsilon: 0.27714603575484437
# Episode 257	Average Score: -142.60 Epsilon: 0.2757603055760701
# Episode 258	Average Score: -142.77 Epsilon: 0.2743815040481898
# Episode 259	Average Score: -144.14 Epsilon: 0.2730095965279488
# Episode 260	Average Score: -143.88 Epsilon: 0.27164454854530906
# Episode 260	Average Score: -143.88
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 261	Average Score: -144.18 Epsilon: 0.2702863258025825
# Episode 262	Average Score: -143.81 Epsilon: 0.2689348941735696
# Episode 263	Average Score: -144.47 Epsilon: 0.26759021970270175
# Episode 264	Average Score: -145.34 Epsilon: 0.2662522686041882
# Episode 265	Average Score: -145.48 Epsilon: 0.2649210072611673
# Episode 266	Average Score: -145.86 Epsilon: 0.26359640222486147
# Episode 267	Average Score: -146.24 Epsilon: 0.26227842021373715
# Episode 268	Average Score: -146.31 Epsilon: 0.2609670281126685
# Episode 269	Average Score: -146.95 Epsilon: 0.25966219297210513
# Episode 270	Average Score: -147.03 Epsilon: 0.2583638820072446
# Episode 270	Average Score: -147.03
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 271	Average Score: -147.48 Epsilon: 0.2570720625972084
# Episode 272	Average Score: -147.48 Epsilon: 0.25578670228422234
# Episode 273	Average Score: -147.09 Epsilon: 0.25450776877280124
# Episode 274	Average Score: -147.43 Epsilon: 0.2532352299289372
# Episode 275	Average Score: -147.56 Epsilon: 0.2519690537792925
# Episode 276	Average Score: -146.07 Epsilon: 0.2507092085103961
# Episode 277	Average Score: -146.09 Epsilon: 0.2494556624678441
# Episode 278	Average Score: -145.83 Epsilon: 0.24820838415550486
# Episode 279	Average Score: -146.21 Epsilon: 0.24696734223472733
# Episode 280	Average Score: -146.94 Epsilon: 0.2457325055235537
# Episode 280	Average Score: -146.94
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 281	Average Score: -144.85 Epsilon: 0.24450384299593592
# Episode 282	Average Score: -145.08 Epsilon: 0.24328132378095624
# Episode 283	Average Score: -145.55 Epsilon: 0.24206491716205145
# Episode 284	Average Score: -146.00 Epsilon: 0.2408545925762412
# Episode 285	Average Score: -145.56 Epsilon: 0.23965031961336
# Episode 286	Average Score: -145.49 Epsilon: 0.2384520680152932
# Episode 287	Average Score: -145.30 Epsilon: 0.23725980767521673
# Episode 288	Average Score: -145.72 Epsilon: 0.23607350863684065
# Episode 289	Average Score: -145.46 Epsilon: 0.23489314109365644
# Episode 290	Average Score: -142.17 Epsilon: 0.23371867538818816
# Episode 290	Average Score: -142.17
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 291	Average Score: -142.63 Epsilon: 0.23255008201124722
# Episode 292	Average Score: -142.63 Epsilon: 0.231387331601191
# Episode 293	Average Score: -142.16 Epsilon: 0.23023039494318503
# Episode 294	Average Score: -142.47 Epsilon: 0.2290792429684691
# Episode 295	Average Score: -141.86 Epsilon: 0.22793384675362674
# Episode 296	Average Score: -141.21 Epsilon: 0.22679417751985861
# Episode 297	Average Score: -140.24 Epsilon: 0.22566020663225933
# Episode 298	Average Score: -141.36 Epsilon: 0.22453190559909803
# Episode 299	Average Score: -141.56 Epsilon: 0.22340924607110255
# Episode 300	Average Score: -141.74 Epsilon: 0.22229219984074702
# Episode 300	Average Score: -141.74
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 301	Average Score: -141.38 Epsilon: 0.2211807388415433
# Episode 302	Average Score: -140.77 Epsilon: 0.22007483514733558
# Episode 303	Average Score: -141.71 Epsilon: 0.2189744609715989
# Episode 304	Average Score: -142.93 Epsilon: 0.2178795886667409
# Episode 305	Average Score: -142.69 Epsilon: 0.2167901907234072
# Episode 306	Average Score: -143.15 Epsilon: 0.21570623976979014
# Episode 307	Average Score: -142.95 Epsilon: 0.21462770857094118
# Episode 308	Average Score: -143.65 Epsilon: 0.21355457002808648
# Episode 309	Average Score: -143.90 Epsilon: 0.21248679717794605
# Episode 310	Average Score: -143.65 Epsilon: 0.21142436319205632
# Episode 310	Average Score: -143.65
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 311	Average Score: -143.32 Epsilon: 0.21036724137609603
# Episode 312	Average Score: -143.58 Epsilon: 0.20931540516921554
# Episode 313	Average Score: -142.47 Epsilon: 0.20826882814336947
# Episode 314	Average Score: -143.15 Epsilon: 0.20722748400265262
# Episode 315	Average Score: -142.46 Epsilon: 0.20619134658263935
# Episode 316	Average Score: -142.88 Epsilon: 0.20516038984972615
# Episode 317	Average Score: -141.58 Epsilon: 0.2041345879004775
# Episode 318	Average Score: -140.76 Epsilon: 0.2031139149609751
# Episode 319	Average Score: -140.97 Epsilon: 0.20209834538617025
# Episode 320	Average Score: -139.84 Epsilon: 0.2010878536592394
# Episode 320	Average Score: -139.84
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 321	Average Score: -140.94 Epsilon: 0.2000824143909432
# Episode 322	Average Score: -141.12 Epsilon: 0.19908200231898848
# Episode 323	Average Score: -141.08 Epsilon: 0.19808659230739353
# Episode 324	Average Score: -143.50 Epsilon: 0.19709615934585656
# Episode 325	Average Score: -142.62 Epsilon: 0.19611067854912728
# Episode 326	Average Score: -142.67 Epsilon: 0.19513012515638165
# Episode 327	Average Score: -142.31 Epsilon: 0.19415447453059972
# Episode 328	Average Score: -144.89 Epsilon: 0.19318370215794672
# Episode 329	Average Score: -144.54 Epsilon: 0.192217783647157
# Episode 330	Average Score: -148.46 Epsilon: 0.1912566947289212
# Episode 330	Average Score: -148.46
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 331	Average Score: -149.08 Epsilon: 0.1903004112552766
# Episode 332	Average Score: -148.78 Epsilon: 0.18934890919900021
# Episode 333	Average Score: -151.87 Epsilon: 0.18840216465300522
# Episode 334	Average Score: -150.74 Epsilon: 0.18746015382974018
# Episode 335	Average Score: -150.57 Epsilon: 0.1865228530605915
# Episode 336	Average Score: -151.30 Epsilon: 0.18559023879528855
# Episode 337	Average Score: -154.01 Epsilon: 0.1846622876013121
# Episode 338	Average Score: -152.11 Epsilon: 0.18373897616330553
# Episode 339	Average Score: -151.94 Epsilon: 0.182820281282489
# Episode 340	Average Score: -152.03 Epsilon: 0.18190617987607657
# Episode 340	Average Score: -152.03
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 341	Average Score: -151.71 Epsilon: 0.18099664897669618
# Episode 342	Average Score: -152.39 Epsilon: 0.1800916657318127
# Episode 343	Average Score: -151.98 Epsilon: 0.17919120740315364
# Episode 344	Average Score: -151.98 Epsilon: 0.17829525136613786
# Episode 345	Average Score: -152.03 Epsilon: 0.17740377510930716
# Episode 346	Average Score: -151.51 Epsilon: 0.17651675623376062
# Episode 347	Average Score: -149.59 Epsilon: 0.1756341724525918
# Episode 348	Average Score: -150.11 Epsilon: 0.17475600159032884
# Episode 349	Average Score: -149.77 Epsilon: 0.17388222158237718
# Episode 350	Average Score: -150.14 Epsilon: 0.1730128104744653
# Episode 350	Average Score: -150.14
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 351	Average Score: -151.86 Epsilon: 0.17214774642209296
# Episode 352	Average Score: -152.30 Epsilon: 0.1712870076899825
# Episode 353	Average Score: -152.27 Epsilon: 0.17043057265153258
# Episode 354	Average Score: -153.06 Epsilon: 0.16957841978827493
# Episode 355	Average Score: -153.25 Epsilon: 0.16873052768933355
# Episode 356	Average Score: -153.57 Epsilon: 0.1678868750508869
# Episode 357	Average Score: -155.71 Epsilon: 0.16704744067563246
# Episode 358	Average Score: -156.35 Epsilon: 0.1662122034722543
# Episode 359	Average Score: -156.68 Epsilon: 0.16538114245489302
# Episode 360	Average Score: -156.49 Epsilon: 0.16455423674261854
# Episode 360	Average Score: -156.49
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 361	Average Score: -156.09 Epsilon: 0.16373146555890544
# Episode 362	Average Score: -156.46 Epsilon: 0.16291280823111093
# Episode 363	Average Score: -156.59 Epsilon: 0.16209824418995536
# Episode 364	Average Score: -156.14 Epsilon: 0.16128775296900558
# Episode 365	Average Score: -155.66 Epsilon: 0.16048131420416054
# Episode 366	Average Score: -154.72 Epsilon: 0.15967890763313974
# Episode 367	Average Score: -155.42 Epsilon: 0.15888051309497406
# Episode 368	Average Score: -155.12 Epsilon: 0.1580861105294992
# Episode 369	Average Score: -154.97 Epsilon: 0.1572956799768517
# Episode 370	Average Score: -156.44 Epsilon: 0.15650920157696743
# Episode 370	Average Score: -156.44
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 371	Average Score: -158.33 Epsilon: 0.1557266555690826
# Episode 372	Average Score: -157.93 Epsilon: 0.1549480222912372
# Episode 373	Average Score: -158.78 Epsilon: 0.15417328217978102
# Episode 374	Average Score: -158.62 Epsilon: 0.1534024157688821
# Episode 375	Average Score: -158.46 Epsilon: 0.1526354036900377
# Episode 376	Average Score: -158.75 Epsilon: 0.1518722266715875
# Episode 377	Average Score: -158.22 Epsilon: 0.15111286553822956
# Episode 378	Average Score: -159.01 Epsilon: 0.15035730121053842
# Episode 379	Average Score: -158.45 Epsilon: 0.14960551470448571
# Episode 380	Average Score: -157.13 Epsilon: 0.14885748713096328
# Episode 380	Average Score: -157.13
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 381	Average Score: -156.87 Epsilon: 0.14811319969530845
# Episode 382	Average Score: -156.32 Epsilon: 0.1473726336968319
# Episode 383	Average Score: -155.71 Epsilon: 0.14663577052834775
# Episode 384	Average Score: -155.34 Epsilon: 0.14590259167570602
# Episode 385	Average Score: -156.94 Epsilon: 0.1451730787173275
# Episode 386	Average Score: -156.78 Epsilon: 0.14444721332374086
# Episode 387	Average Score: -157.39 Epsilon: 0.14372497725712216
# Episode 388	Average Score: -157.42 Epsilon: 0.14300635237083656
# Episode 389	Average Score: -157.91 Epsilon: 0.14229132060898236
# Episode 390	Average Score: -157.99 Epsilon: 0.14157986400593744
# Episode 390	Average Score: -157.99
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 391	Average Score: -157.59 Epsilon: 0.14087196468590776
# Episode 392	Average Score: -157.71 Epsilon: 0.14016760486247823
# Episode 393	Average Score: -157.82 Epsilon: 0.13946676683816583
# Episode 394	Average Score: -157.04 Epsilon: 0.138769433003975
# Episode 395	Average Score: -156.67 Epsilon: 0.13807558583895513
# Episode 396	Average Score: -156.65 Epsilon: 0.13738520790976036
# Episode 397	Average Score: -156.67 Epsilon: 0.13669828187021155
# Episode 398	Average Score: -155.32 Epsilon: 0.13601479046086049
# Episode 399	Average Score: -155.52 Epsilon: 0.1353347165085562
# Episode 400	Average Score: -154.77 Epsilon: 0.1346580429260134
# Episode 400	Average Score: -154.77
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 401	Average Score: -154.21 Epsilon: 0.13398475271138335
# Episode 402	Average Score: -153.97 Epsilon: 0.13331482894782642
# Episode 403	Average Score: -154.42 Epsilon: 0.13264825480308728
# Episode 404	Average Score: -152.97 Epsilon: 0.13198501352907185
# Episode 405	Average Score: -153.48 Epsilon: 0.1313250884614265
# Episode 406	Average Score: -152.82 Epsilon: 0.13066846301911936
# Episode 407	Average Score: -153.34 Epsilon: 0.13001512070402377
# Episode 408	Average Score: -152.99 Epsilon: 0.12936504510050365
# Episode 409	Average Score: -153.10 Epsilon: 0.12871821987500112
# Episode 410	Average Score: -154.16 Epsilon: 0.12807462877562611
# Episode 410	Average Score: -154.16
# INFO:tensorflow:Assets written to: checkpoint.target.ckpt/assets
# INFO:tensorflow:Assets written to: checkpoint.local.ckpt/assets
# Episode 411	Average Score: -155.75 Epsilon: 0.12743425563174798
# Episode 412	Average Score: -155.93 Epsilon: 0.12679708435358925
# Episode 413	Average Score: -154.80 Epsilon: 0.1261630989318213
